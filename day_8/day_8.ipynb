# %%
from collections import defaultdict
from itertools import combinations

# %%
# with open("test_input.txt") as f:
with open("input.txt") as f:
    lines = f.readlines()
lines = [line.strip() for line in lines]
# lines

# %%
grid = [list(line) for line in lines]
rows = len(grid)
cols = len(grid[0])
rows, cols
# Out:
# (50, 50)

# %%
def print_grid(grid):
    for row in grid:
        print("".join(row))
print_grid(grid)
# Out:
# ..........M..........j.............y.....O........
# ...B...............q......m........lGO............
# ....................q......2.l.GQ...O.............
# .....X.......................................4....
# .....................q............................
# ....M......P...............xl.K.............2.....
# ....F.........L.......C.K..............m..........
# ..........FM......P....jy......m..........o...r...
# ..X.......P.....RL..............G..x..........4...
# ............L..........NC.....q...................
# .....C.X...............K....y..........4..........
# ........S...R.............j.x.....V...4...........
# .....................R..x.....V..i......m.........
# ...........................R.V......N.......X.....
# .....F.........M......N......E....................
# ................v................T.......F......O.
# .............................N...V.......Q........
# ...v.....................C.....i..................
# ...

# %%
freqs = defaultdict(list)
freqs_list = []
for i in range(rows):
    for j in range(cols):
        if grid[i][j] != ".":
            freqs[grid[i][j]].append((i,j))
            freqs_list.append((i,j))
# freqs

# %%
for freq in freqs:
    print(freq, freqs[freq])
# Out:
# M [(0, 10), (5, 4), (7, 11), (14, 15)]
# j [(0, 21), (7, 23), (11, 26), (20, 34)]
# y [(0, 35), (7, 24), (10, 28)]
# O [(0, 41), (1, 37), (2, 36), (15, 48)]
# B [(1, 3), (30, 9), (38, 0), (45, 8)]
# q [(1, 19), (2, 20), (4, 21), (9, 30)]
# m [(1, 26), (6, 39), (7, 31), (12, 40)]
# l [(1, 35), (2, 29), (5, 28)]
# G [(1, 36), (2, 31), (8, 32), (25, 35)]
# 2 [(2, 27), (5, 44), (21, 49), (22, 24)]
# Q [(2, 32), (16, 41), (19, 42), (25, 43)]
# X [(3, 5), (8, 2), (10, 7), (13, 44)]
# 4 [(3, 45), (8, 46), (10, 39), (11, 38)]
# P [(5, 11), (7, 18), (8, 10), (24, 19)]
# x [(5, 27), (8, 35), (11, 28), (12, 24)]
# K [(5, 30), (6, 24), (10, 23), (27, 37)]
# F [(6, 4), (7, 10), (14, 5), (15, 41)]
# L [(6, 14), (8, 17), (9, 12), (49, 21)]
# C [(6, 22), (9, 24), (10, 5), (17, 25)]
# o [(7, 42), (35, 13), (44, 45), (48, 44)]
# r [(7, 46), (23, 49), (24, 47), (28, 30)]
# R [(8, 16), (11, 12), (12, 21), (13, 27)]
# N [(9, 23), (13, 36), (14, 22), (16, 29)]
# S [(11, 8), (41, 31), (42, 25), (46, 10)]
# ...

# %%
for combo in combinations(freqs["0"], 2):
    print(combo)
# Out:
# ((21, 9), (22, 25))
# ((21, 9), (23, 8))
# ((21, 9), (24, 14))
# ((22, 25), (23, 8))
# ((22, 25), (24, 14))
# ((23, 8), (24, 14))

# %%
# a, b = ((2, 5), (4, 4))
a, b = ((4, 4), (6, 4))
x_diff = abs(a[0]-b[0])
y_diff = abs(a[1]-b[1])
print(x_diff, y_diff)

print(a[1] < b[1])
if a[1] < b[1]:
    print(min(a[0], b[0])-(x_diff), min(a[1], b[1])-(y_diff))
    print(max(a[0], b[0])+(x_diff), max(a[1], b[1])+(y_diff))
else:
    print(max(a[0], b[0])+(x_diff), min(a[1], b[1])-(y_diff))
    print(min(a[0], b[0])-(x_diff), max(a[1], b[1])+(y_diff))
# Out:
# 2 0
# False
# 8 4
# 2 4

# %%
# a, b = ((2, 5), (4, 4))
a, b = ((4, 4), (6, 4))
x_diff = b[0]-a[0]
y_diff = b[1]-a[1]
print(x_diff, y_diff)

b[0]+x_diff, b[1] + y_diff
a[0]-x_diff, a[1] - y_diff


x_diff = a[0]-b[0]
y_diff = a[1]-b[1]
print(x_diff, y_diff)

b[0]-x_diff, b[1] - y_diff
a[0]+x_diff, a[1] + y_diff


# print(a[1] < b[1])
# if a[1] < b[1]:
#     print(min(a[0], b[0])-(x_diff), min(a[1], b[1])-(y_diff))
#     print(max(a[0], b[0])+(x_diff), max(a[1], b[1])+(y_diff))
# else:
#     print(max(a[0], b[0])+(x_diff), min(a[1], b[1])-(y_diff))
#     print(min(a[0], b[0])-(x_diff), max(a[1], b[1])+(y_diff))
# Out:
# 2 0
# -2 0
# (2, 4)

# %%
test_grid = [list(line) for line in lines]

test_grid[4][4] = "X"
test_grid[6][4] = "X"

test_grid[8][4] = "#"
test_grid[2][4] = "#"

# test_grid[2][5] = "X"
# test_grid[4][4] = "X"
# test_grid[3][7] = "X"


# test_grid[0][6] = "#"
# test_grid[6][3] = "#"

# test_grid[1][3] = "#"
# test_grid[4][9] = "#"

test_grid
# Out:
# [['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'M',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'j',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'y',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'O',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   'B',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'q',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'm',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'l',
#   'G',
#   'O',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
# ...

# %%
def generate_antinodes(freq_list):
    antinodes = set()
    for combo in combinations(freq_list, 2):
        a, b = combo
#         x_diff = a[0] - b[0]
#         y_diff = a[1] - b[1]
        
        x_diff = b[0]-a[0]
        y_diff = b[1]-a[1]
#         print(x_diff, y_diff)

#         b[0]+x_diff, b[1] + y_diff
#         a[0]-x_diff, a[1] - y_diff
        
#         antinodes.append((b[0]-x_diff, b[1] - y_diff))
#         antinodes.append((a[0]+x_diff, a[1] + y_diff))
        antinodes.add((b[0]+x_diff, b[1] + y_diff))
        antinodes.add((a[0]-x_diff, a[1] - y_diff))
        
#         if a[1] < b[1]:
#             antinodes.append((min(a[0], b[0])-(x_diff), min(a[1], b[1])-(y_diff)))
#             antinodes.append((max(a[0], b[0])+(x_diff), max(a[1], b[1])+(y_diff)))
#         else:
#             antinodes.append((max(a[0], b[0])+(x_diff), min(a[1], b[1])-(y_diff)))
#             antinodes.append((min(a[0], b[0])-(x_diff), max(a[1], b[1])+(y_diff)))



    return antinodes
# print(generate_antinodes(freqs["A"]))
print(sorted(generate_antinodes(freqs["0"])))
# Out:
# [(18, 4), (19, 10), (20, -7), (20, 36), (21, 42), (22, 2), (23, 41), (24, -9), (25, 7), (25, 20), (26, 3), (27, 19)]

# %%
set([(18, 4), (19, 10), (20, -7), (20, 36), (21, 9), (21, 42), (22, 2), (22, 25), (23, 8), (23, 41), (24, -9), (24, 14), (25, 7), (25, 20), (26, 3), (27, 19)]) - set([(18, 4), (19, 10), (20, -7), (20, 36), (21, 42), (22, 2), (23, 41), (24, -9), (25, 7), (25, 20), (26, 3), (27, 19)])
# Out:
# {(21, 9), (22, 25), (23, 8), (24, 14)}

# %%
antinodes = []
for freq in freqs:
#     print(freq, freqs[freq])
    antinodes += generate_antinodes(freqs[freq])
    
len(set(antinodes))
# Out:
# 664

# %%
antinode_grid = [list(line) for line in lines]
valid_antinodes = set()
for antinode in antinodes:
    if 0 <= antinode[0] < rows and 0 <= antinode[1] < cols:# and antinode not in freqs_list:
        antinode_grid[antinode[0]][antinode[1]] = "#"
        valid_antinodes.add(antinode)

print(len(valid_antinodes))
print_grid(antinode_grid)
# Out:
# 398
# .......#..M....#..##.j.............y.##..#........
# ...B........#......q...#..m........lGO........#...
# .......#....#....####.#..#.2.l.GQ#..O..#........#.
# ....##..........#.#.##.#..#........#.........4....
# ...........#........#q..##....##....#.........#...
# ....M.....#P.#..#...#.....#xl.K.........#.#.2..#..
# ....F.........L.......#.K.#.#......#...m..........
# .......#..FM......#...###......m...#...#..o...r...
# ..X#......P.....#L.....#...#...#G..x.......#..4...
# ..##.......#L.....#..#.NC#....q........##.........
# ...#.C.#........#...#.#K.#..y...#.....#4...#......
# .....#..S#..R#.#..........j.x..#..V...4....#......
# .....#....#.#..#..#..R..x.#...V.#i...#..m.........
# .............#......#...#.#R.##.#...#..###..X..#..
# .....F..#...##.M.....##..#..#E#..#.....#..........
# ......#.#.#.....#......##.#.##...T.......F#.....O.
# ....#.#..##..#............#..N...V.....##Q........
# ...v#....#....#..#....#..C...#.i.#.......#.......#
# ...
